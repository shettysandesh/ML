# %%
import numpy as np
import pandas as pd
from sklearn import metrics
from pandas.plotting import scatter_matrix 
import matplotlib.pyplot as plt 
from sklearn import model_selection 
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
train = pd.read_csv("house sale.csv")
train.describe()
# Out:
#            Number    Bedrooms       Baths   SquareFeet    YearBuilt  \
# count  929.000000  929.000000  929.000000   929.000000   929.000000
# mean   465.000000    3.194833    1.779333  1552.539290  1945.903122
# std    268.323499    0.943293    0.743154   685.007177    37.209902
# min      1.000000    0.000000    0.000000     0.000000  1870.000000
# 25%    233.000000    3.000000    1.000000  1136.000000  1900.000000
# 50%    465.000000    3.000000    1.750000  1423.000000  1956.000000
# 75%    697.000000    4.000000    2.000000  1824.000000  1973.000000
# max    929.000000    8.000000    6.000000  6815.000000  2013.000000
#
#           YearSold  CostPerSqFt      SalePrice
# count   929.000000   929.000000     929.000000
# mean   2009.365985    83.291561  133203.720129
# std       3.124149    35.762241   77959.624697
# min    2005.000000     0.000000    7000.000000
# 25%    2007.000000    60.820000   83000.000000
# 50%    2009.000000    82.880000  119340.000000
# 75%    2012.000000   105.770000  162500.000000
# max    2015.000000   258.790000  606000.000000

# %%
feature_names = ['Bedrooms','Baths','SquareFeet','YearBuilt','YearSold']

# %%
data = pd.DataFrame()

# %%
data['Bedrooms']=train['Bedrooms']
data['Baths']=train['Baths']
data['SquareFeet']=train['SquareFeet']
data['YearBuilt']=train['YearBuilt']
data['YearSold']=train['YearSold']
data['SalePrice']=train['SalePrice']

# %%
data.head()
# Out:
#    Bedrooms  Baths  SquareFeet  YearBuilt  YearSold  SalePrice
# 0         2    1.0        1120       1993      2005       7000
# 1         3    1.0        1224       1900      2006      27000
# 2         4    1.0        1540       1970      2006      28000
# 3         3    1.0        1154       1900      2006      30000
# 4         3    1.0        1277       1900      2005      30750

# %%
X = data[feature_names]
X
# Out:
#      Bedrooms  Baths  SquareFeet  YearBuilt  YearSold
# 0           2    1.0        1120       1993      2005
# 1           3    1.0        1224       1900      2006
# 2           4    1.0        1540       1970      2006
# 3           3    1.0        1154       1900      2006
# 4           3    1.0        1277       1900      2005
# ..        ...    ...         ...        ...       ...
# 924         4    3.0        1920       2006      2014
# 925         4    3.0        2958       1968      2014
# 926         4    3.0        3359       1993      2014
# 927         3    2.5        1565       1987      2015
# 928         5    6.0        3792       1990      2014
#
# [929 rows x 5 columns]

# %%
y = data.SalePrice
y.values.ravel()
print(y)
# Out:
# 0        7000
# 1       27000
# 2       28000
# 3       30000
# 4       30750
#         ...
# 924    325000
# 925    360000
# 926    362500
# 927    405000
# 928    606000
# Name: SalePrice, Length: 929, dtype: int64

# %%
plt.scatter(data['Bedrooms'], data['SalePrice'])
plt.title('Bedrooms v/s SalePrice Graph')
plt.xlabel('Bedrooms')
plt.ylabel('SalePrice')
plt.plot()
# Out:
# []

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20, random_state=20)

# %%
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import r2_score
model=ExtraTreesRegressor()
model.fit(X_train,y_train)
prediction = model.predict(X_test)
r2score=eval("%.2f" % r2_score(y_test,prediction))
rmse=np.sqrt(mean_squared_error(y_test,prediction))
# Out:
# c:\users\lenovo\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
r2score
# Out:
# 0.7

# %%
rmse
# Out:
# 44187.13876944164

# %%
naming=['Bedrooms','Baths','SquareFeet','YearBuilt','YearSold']
B=[]
print("ENTER VALUE FOR\n")
for i in naming:
  print(i)
  B.append(input())
X_value=np.reshape(B,(1, -1))
getresult=ExtraTreesRegressor()
getresult.fit(X_train,y_train)
predictions=getresult.predict(X_value)
print("Computer Price:\r")
print(predictions.astype('int'))
# Out:
# ENTER VALUE FOR
#
# Bedrooms
# 2
# Baths
# 1
# SquareFeet
# 1120
# YearBuilt
# 1993
# YearSold
# 2005
# Computer Price:
# [7000]
# c:\users\lenovo\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
